# %%
class Value:
  def __init__(self, inValue, inOperation = "", inChildren = None):
    self.value = float(inValue)
    self.grad = 0.0
    self.operation = inOperation
    self.children = [children for children in inChildren if children is not None]

    
  def __repr__(self):
    return f"Value({self.value}), {self.operation}, {self.children}"

  # Operators

  def __add__(self, other):
    out = Value(self.value + other.value, "add", [self, other])
    
    return out

  def __sub__(self, other):
    out = Value(self.value - other.value, "sub", [self, other])
    
    return out
  
  def __neg__(self):
    return Value(- self.value)

  def __mul__(self, other):
    out = Value(self.value * other.value, "mul", [self, other])
    
    return out

  def __pow__(self, inPow):
    out = Value(self.value ** inPow, "pow", [self])
    return out

  def __truediv__ (self, other):
    out = Value(self.value / other.value, "div", [self, other])
    return out
  
a = Value(3.0)
b = Value(2.0)

print(a + b)
print(a - b)
print(a * b)
print(a**2)
print(a / b)
# Out:
# Value(5.0), add, [Value(3.0), , [], Value(2.0), , []]
# Value(1.0), sub, [Value(3.0), , [], Value(2.0), , []]
# Value(6.0), mul, [Value(3.0), , [], Value(2.0), , []]
# Value(9.0), pow, [Value(3.0), , []]
# Value(1.5), div, [Value(3.0), , [], Value(2.0), , []]
